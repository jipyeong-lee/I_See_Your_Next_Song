# %%
# !pip3 uninstall torch torchvision torchaudio
# !pip3 install torch==1.9.0+cu111 torchvision==0.10.0+cu111 torchaudio==0.9.0 -f https://download.pytorch.org/whl/torch_stable.html
# Out:
# Found existing installation: torch 1.12.1+cu113
# Uninstalling torch-1.12.1+cu113:
#   Would remove:
#     /usr/local/bin/convert-caffe2-to-onnx
#     /usr/local/bin/convert-onnx-to-caffe2
#     /usr/local/bin/torchrun
#     /usr/local/lib/python3.7/dist-packages/caffe2/*
#     /usr/local/lib/python3.7/dist-packages/torch-1.12.1+cu113.dist-info/*
#     /usr/local/lib/python3.7/dist-packages/torch/*
#     /usr/local/lib/python3.7/dist-packages/torchgen/*
# Proceed (y/n)? ㅛ
# Your response ('ㅛ') was not one of the expected responses: y, n
# Proceed (y/n)? ㅛ
# Your response ('ㅛ') was not one of the expected responses: y, n
# Proceed (y/n)? y
#   Successfully uninstalled torch-1.12.1+cu113
# Found existing installation: torchvision 0.13.1+cu113
# Uninstalling torchvision-0.13.1+cu113:
#   Would remove:
#     /usr/local/lib/python3.7/dist-packages/torchvision-0.13.1+cu113.dist-info/*
#     /usr/local/lib/python3.7/dist-packages/torchvision.libs/libcudart.053364c0.so.11.0
# ...

# %%
# !nvcc --version
# !nvidia-smi
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2021 NVIDIA Corporation
# Built on Sun_Feb_14_21:12:58_PST_2021
# Cuda compilation tools, release 11.2, V11.2.152
# Build cuda_11.2.r11.2/compiler.29618528_0
# Wed Nov  2 07:03:20 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   48C    P8    12W /  70W |      0MiB / 15109MiB |      0%      Default |
# ...

# %%
# !git clone https://github.com/jipyeong-lee/contrastive-singing-voices
# Out:
# Cloning into 'contrastive-singing-voices'...
# remote: Enumerating objects: 32, done.
# remote: Counting objects: 100% (32/32), done.
# remote: Compressing objects: 100% (31/31), done.
# remote: Total 32 (delta 13), reused 10 (delta 0), pack-reused 0
# Unpacking objects: 100% (32/32), done.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %%bash
# cd contrastive-singing-voices
# pip install -r requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.21.6
#     Uninstalling numpy-1.21.6:
#       Successfully uninstalled numpy-1.21.6
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
#   Attempting uninstall: six
#     Found existing installation: six 1.15.0
#     Uninstalling six-1.15.0:
#       Successfully uninstalled six-1.15.0
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.17.3
#     Uninstalling protobuf-3.17.3:
#       Successfully uninstalled protobuf-3.17.3
#   Attempting uninstall: Pillow
#     Found existing installation: Pillow 7.1.2
#     Uninstalling Pillow-7.1.2:
#       Successfully uninstalled Pillow-7.1.2
#   Attempting uninstall: idna
#     Found existing installation: idna 2.10
# ...

# %%
# !python contrastive-singing-voices/train.py \
--data_path '/content/drive/MyDrive/Colab Notebooks/D&A_Conference/Final_dataset/' \
--save_path '/content/drive/MyDrive/Colab Notebooks/D&A_Conference/model/save_folder_지평/' \
--seed 42  \
--pitch 'pos' \
--stretch 'pos' \
--num_workers 0 \
--batch_size 32 \
--resume '/content/drive/MyDrive/Colab Notebooks/D&A_Conference/model/save_folder_지평/train_20221026_143352/ckpt/ckpt_epoch_50.pth'
# Out:
# {'epochs': 150, 'print_freq': 10, 'save_freq': 5, 'batch_size': 32, 'num_workers': 0, 'n_fft': 800, 'input_len': 80000, 'learning_rate': 0.01, 'weight_decay': 0.0001, 'resume': '/content/drive/MyDrive/Colab Notebooks/D&A_Conference/model/save_folder_지평/train_20221026_143352/ckpt/ckpt_epoch_50.pth', 'softmax': True, 'nce_k': 4096, 'nce_t': 0.07, 'nce_m': 0.5, 'pitch': 'pos', 'stretch': 'pos', 'feat_dim': 256, 'dropout': 0.1, 'data_path': '/content/drive/MyDrive/Colab Notebooks/D&A_Conference/Final_dataset/', 'save_path': '/content/drive/MyDrive/Colab Notebooks/D&A_Conference/model/save_folder_지평/', 'seed': 42, 'model_name': 'train_20221102_070425', 'model_folder': '/content/drive/MyDrive/Colab Notebooks/D&A_Conference/model/save_folder_지평/train_20221102_070425/ckpt', 'tb_folder': '/content/drive/MyDrive/Colab Notebooks/D&A_Conference/model/save_folder_지평/train_20221102_070425/logs'}
# ...

# %%
# !python contrastive-singing-voices/train.py \
# --data_path '/content/drive/MyDrive/Colab Notebooks/D&A_Conference/data/Final_dataset/' \
# --save_path '/content/drive/MyDrive/Colab Notebooks/D&A_Conference/model/save_folder/' \
# --seed 42  \
# --pitch 'pos' \
# --stretch 'neg' \
# --num_workers 0 \
# --batch_size 32

# %%
# !python contrastive-singing-voices/train.py \
# --data_path '/content/drive/MyDrive/Colab Notebooks/D&A_Conference/data/Final_dataset/' \
# --save_path '/content/drive/MyDrive/Colab Notebooks/D&A_Conference/model/save_folder/' \
# --seed 42  \
# --pitch 'neg' \
# --stretch 'pos' \
# --num_workers 0 \
# --batch_size 32

# %%
# !python contrastive-singing-voices/train.py \
# --data_path '/content/drive/MyDrive/Colab Notebooks/D&A_Conference/data/Final_dataset/' \
# --save_path '/content/drive/MyDrive/Colab Notebooks/D&A_Conference/model/save_folder/' \
# --seed 42  \
# --pitch 'neg' \
# --stretch 'neg' \
# --num_workers 0 \
# --batch_size 32

# %%
# !python contrastive-singing-voices/train.py \
# --data_path '/content/drive/MyDrive/Colab Notebooks/D&A_Conference/data/Final_dataset/' \
# --save_path '/content/drive/MyDrive/Colab Notebooks/D&A_Conference/model/save_folder/' \
# --seed 42  \
# --pitch 'none' \
# --stretch 'none' \
# --num_workers 0 \
# --batch_size 32
