# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/Colab Notebooks/streamlit/
# Out:
# /content/drive/MyDrive/Colab Notebooks/streamlit

# %%
# !pip install -r requirements.txt

# %%
# !pip install pyngrok

# %%
#https://dashboard.ngrok.com/get-started/setup
# 성현 - 2HzNjZngK2g2HJ469AwB4TrzwAo_5ndY8ZafnHW2exv4xf9XB
# 보현 - 2I0FoLlbbvuNjoBidbZxBb5Nc3k_Urbvog34xtnVWJRyp1ym
# !ngrok authtoken 2HzNjZngK2g2HJ469AwB4TrzwAo_5ndY8ZafnHW2exv4xf9XB

# %%
from pyngrok import ngrok

# %%
# !streamlit run test_stream_v2.py&>/dev/null&

# %%
publ_url = ngrok.connect(addr='8501')

# %%
# 동영상을 음성 파일로 변환하는 링크
# https://www.freeconvert.com/download

# %%
publ_url

# %%
# !ps
# Out:
#     PID TTY          TIME CMD
#       1 ?        00:00:00 docker-init
#       7 ?        00:00:03 node
#      11 ?        00:00:00 run.sh
#      12 ?        00:00:02 kernel_manager_
#      27 ?        00:00:00 tail
#      37 ?        00:00:03 python3 <defunct>
#      38 ?        00:00:00 colab-fileshim.
#      65 ?        00:00:02 jupyter-noteboo
#      66 ?        00:00:00 dap_multiplexer
#      80 ?        00:00:07 python3
#      98 ?        00:00:02 python3
#     148 ?        00:00:00 bash
#     149 ?        00:00:00 drive
#     150 ?        00:00:00 grep
#     224 ?        00:00:04 drive
#     302 ?        00:00:00 bash
#     303 ?        00:00:00 directoryprefet
#     304 ?        00:00:00 tail
#     305 ?        00:00:00 python3
#     430 ?        00:00:06 node
#    1190 ?        00:00:00 ps

# %%
# !kill 455 
ngrok.kill()
