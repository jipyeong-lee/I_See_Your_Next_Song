# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import rc 
rc('font', family='malgun.ttf')
plt.rcParams['axes.unicode_minus'] = False

# %%
#pp = pd.read_csv("pp.csv")
# pn = pd.read_csv("extract/pn.csv")
# neg_pos = pd.read_csv("extract/np.csv")
pp_df = pd.read_csv("tcae_charlie_embedding.csv")

# %%
nn = pd.read_csv('extract/nn.csv') ; nn
# Out:
#      Final_dataset/이정_겨울봄.wav  Final_dataset/버즈_거짓말.wav  \
# 0                    0.034369                  0.022882
# 1                   -0.031024                  0.016553
# 2                   -0.020527                 -0.008592
# 3                    0.030959                 -0.108208
# 4                    0.010709                  0.025253
# ..                        ...                       ...
# 251                 -0.009150                 -0.063537
# 252                  0.038770                 -0.023642
# 253                  0.014856                 -0.025773
# 254                  0.005369                  0.094368
# 255                 -0.020678                  0.077542
#
#      Final_dataset/김광석_너무 깊이 생각하지마.wav  Final_dataset/소찬휘_크게 라디오를 켜고.wav  \
# 0                            -0.004442                         -0.118818
# 1                             0.032392                          0.082228
# 2                             0.017633                         -0.011737
# 3                            -0.015488                         -0.107402
# 4                             0.001751                          0.082599
# ..                                 ...                               ...
# 251                           0.013013                          0.068113
# 252                           0.010195                         -0.078405
# 253                           0.005730                          0.051498
# 254                           0.023932                         -0.057625
# 255                          -0.004051                          0.068362
#
#      Final_dataset/이적_당연한 것들.wav  Final_dataset/김연자_번지없는 주막.wav  \
# 0                       0.085881                      -0.024572
# 1                       0.018102                       0.061289
# 2                       0.011530                       0.026504
# 3                      -0.005438                      -0.010933
# 4                       0.018938                       0.042020
# ..                           ...                            ...
# 251                     0.002571                       0.022174
# 252                    -0.007707                       0.029544
# 253                    -0.024107                      -0.003572
# 254                     0.090591                       0.002541
# 255                     0.032875                      -0.000446
#
#      Final_dataset/김종국_Good Bye.wav  Final_dataset/김예림_YELLOW.wav  \
# 0                          0.087600                     -0.050033
# 1                         -0.023606                      0.031281
# 2                          0.079307                      0.019837
# 3                          0.040562                      0.049203
# 4                          0.088638                     -0.018396
# ..                              ...                           ...
# 251                       -0.059838                     -0.081374
# 252                        0.051319                     -0.071593
# 253                       -0.052620                     -0.037136
# 254                        0.065931                      0.028356
# 255                       -0.065697                      0.057967
#
#      Final_dataset/박현빈_댄싱퀸.wav  Final_dataset/거미_그래도 사랑이었잖아.wav  ...  \
# 0                     0.049349                         0.015639  ...
# 1                     0.040607                        -0.013096  ...
# 2                     0.078437                        -0.009611  ...
# 3                    -0.006659                         0.044888  ...
# 4                     0.072290                        -0.000190  ...
# ..                         ...                              ...  ...
# 251                  -0.060741                         0.012036  ...
# 252                  -0.037989                         0.013314  ...
# 253                   0.006542                         0.011070  ...
# 254                   0.078511                        -0.008257  ...
# 255                   0.038652                        -0.035908  ...
#
#      Final_dataset/별_왜 모르니.wav  Final_dataset/이적_그런걸까.wav  \
# 0                    -0.034822                  -0.011160
# 1                     0.019735                   0.113502
# 2                    -0.090643                   0.131119
# 3                     0.038260                  -0.084461
# 4                    -0.025538                   0.012335
# ..                         ...                        ...
# 251                  -0.025248                   0.027564
# 252                   0.019809                   0.011275
# 253                   0.003230                  -0.039350
# 254                  -0.005520                   0.081858
# 255                   0.023634                   0.014781
#
#      Final_dataset/서문탁_가거라 사랑아.wav  Final_dataset/신해철_사탄의 신부.wav  \
# 0                         0.000145                     -0.063298
# 1                         0.039617                      0.050731
# 2                         0.029917                      0.053141
# 3                        -0.065800                     -0.125646
# 4                         0.034008                      0.089900
# ..                             ...                           ...
# 251                      -0.052150                      0.021656
# 252                      -0.000975                     -0.080393
# 253                      -0.035774                      0.002545
# 254                       0.029370                      0.010150
# 255                       0.028278                      0.057638
#
#      Final_dataset/양다일_Darling.wav  Final_dataset/장나라_I Love School.wav  \
# 0                        -0.025086                            -0.088234
# 1                        -0.072753                             0.028704
# 2                        -0.098745                            -0.026202
# 3                        -0.013571                            -0.027805
# 4                         0.128049                            -0.095718
# ..                             ...                                  ...
# 251                       0.089817                            -0.019389
# 252                      -0.014573                            -0.076234
# 253                       0.025004                             0.051714
# 254                      -0.063566                             0.004568
# 255                      -0.046757                             0.074280
#
#      Final_dataset/식케이_이해해줘 (Somebody Else).wav  \
# 0                                      0.151876
# 1                                      0.040324
# 2                                      0.043356
# 3                                     -0.064274
# 4                                      0.118669
# ..                                          ...
# 251                                   -0.010101
# 252                                   -0.036981
# 253                                   -0.129844
# 254                                    0.160636
# 255                                    0.061416
#
#      Final_dataset/존박_내가 다 줄게요.wav  Final_dataset/김창완_동네길.wav  \
# 0                        -0.000522                   0.033505
# 1                        -0.018241                   0.037983
# 2                        -0.025443                   0.072830
# 3                        -0.126524                   0.016848
# 4                         0.046691                   0.025276
# ..                             ...                        ...
# 251                      -0.010993                  -0.003186
# 252                       0.030367                  -0.071601
# 253                       0.026728                   0.043805
# 254                      -0.022843                   0.064978
# 255                      -0.000284                   0.038130
#
#      Final_dataset/김완선_나홀로 뜰 앞에서.wav
# 0                          -0.085476
# 1                           0.075864
# 2                          -0.060009
# 3                          -0.024219
# 4                          -0.099245
# ..                               ...
# 251                         0.048584
# 252                        -0.067916
# 253                         0.069817
# 254                        -0.051567
# 255                         0.075953
#
# [256 rows x 4500 columns]

# %%
nn = nn.T.reset_index()
nn['singer'] = nn['index'].apply(lambda x : x.split('/')[1].split('_')[0])
nn['song'] = nn['index'].apply(lambda x : x.split('/')[1].split('_')[1].split('.')[0])

# %%
pp_df = pd.concat([pp_df,nn[['singer','song']]],axis=1)

# %%
pp_df
# Out:
#               0          1          2          3          4          5  \
# 0     -8.513019  -8.222455  -6.705440  -8.468358  -8.844224  -8.796428
# 1     -2.917049  -2.854013  -2.507752  -2.887567  -2.975231  -3.076069
# 2     -6.519131  -6.498351  -4.584888  -6.472404  -6.401877  -6.511225
# 3     -7.877540  -7.780499  -7.534731  -7.891391  -8.202155  -8.272341
# 4    -16.228971 -16.193554 -10.183735 -16.631863 -17.103890 -17.275978
# ...         ...        ...        ...        ...        ...        ...
# 4495  -1.251253  -1.267070  -0.397847  -1.339894  -1.358568  -1.332658
# 4496  -8.586628  -8.336636  -5.443604  -8.165878  -8.220989  -8.864051
# 4497  -5.675000  -5.571161  -4.912778  -5.627340  -5.780156  -5.861499
# 4498  -6.936581  -7.183513  -4.422243  -7.105662  -7.304242  -7.338390
# 4499  -0.748063  -0.748581  -0.615630  -0.773263  -0.798047  -0.785766
#
#               6          7          8          9  ...        248        249  \
# 0     -4.719296  -8.830245  -8.579269  -8.163067  ...  -8.708296  -1.427878
# 1     -2.996600  -3.076011  -3.037739  -2.811982  ...  -2.977069  11.546661
# 2     -4.751239  -6.529784  -6.684850  -6.238879  ...  -6.641293  -4.262462
# 3     -8.526191  -8.238724  -8.119158  -7.491746  ...  -7.926594 -10.435346
# 4    -13.294459 -17.584250 -16.726784 -15.613342  ... -17.346731 -21.777718
# ...         ...        ...        ...        ...  ...        ...        ...
# 4495  -0.830237  -1.310818  -1.289522  -1.211672  ...  -1.350890  -2.679624
# 4496  -7.853318  -8.629366  -8.683916  -8.298646  ...  -8.578732  -8.393202
# 4497  -5.608804  -5.971799  -6.007567  -5.394020  ...  -5.803029  -2.580112
# 4498  -5.357388  -7.394545  -7.232494  -6.946477  ...  -7.361902  -4.398164
# 4499  -0.690716  -0.816560  -0.775371  -0.727529  ...  -0.791457  14.033855
#
#             250        251        252        253        254        255  \
# 0     -8.587887  -9.569829  -9.054489  -9.988266  -9.881259 -12.810556
# 1     -2.817561  -3.347707  -3.040459  -3.470632  -3.422362  -3.756182
# 2     -6.734391  -7.240643  -6.578429  -7.795474  -7.264943  -5.475534
# 3     -7.674200  -9.076702  -8.448717  -9.432220  -9.233482  -1.094698
# 4    -16.502188 -18.739855 -17.677925 -19.637020 -19.204475  -9.624725
# ...         ...        ...        ...        ...        ...        ...
# 4495  -1.335108  -1.431214  -1.346849  -1.490216  -1.466784  -2.731017
# 4496  -8.009551  -9.390750  -8.512573  -9.878328  -9.485591  -3.495023
# 4497  -5.552907  -6.489516  -5.957396  -6.766101  -6.623311  23.463005
# 4498  -7.055368  -7.920496  -7.422000  -8.303159  -8.138977 -13.189854
# 4499  -0.763747  -0.864317  -0.826920  -0.901001  -0.881752  -1.062599
#
#       singer                  song
# 0         이정                   겨울봄
# 1         버즈                   거짓말
# 2        김광석           너무 깊이 생각하지마
# 3        소찬휘            크게 라디오를 켜고
# 4         이적                당연한 것들
# ...      ...                   ...
# 4495     장나라         I Love School
# 4496     식케이  이해해줘 (Somebody Else)
# 4497      존박              내가 다 줄게요
# 4498     김창완                   동네길
# 4499     김완선             나홀로 뜰 앞에서
#
# [4500 rows x 258 columns]

# %%
from sklearn.decomposition import PCA
pp_df_pca = PCA().fit(pp_df.iloc[:, :-2])

# %%
import numpy as np
cumsum = np.cumsum(pp_df_pca.explained_variance_ratio_)

# %%
import matplotlib.pylab as plt
import seaborn as sns
fig ,ax = plt.subplots(1,1, figsize = (8, 6))
sns.lineplot(np.arange(1,pp_df.iloc[:, :-2].shape[1]+1),np.cumsum(pp_df_pca.explained_variance_ratio_), marker = 'o', ax=ax )
plt.grid()
plt.xlabel('Number of PCA')
plt.ylabel('Explained variance ratio')
plt.show()
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ## UMAP

# %%
import umap

# %%
reducer = umap.UMAP()

# %%
embedding = reducer.fit_transform(pp_df.iloc[:, :-2])
embedding.shape
# Out:
# (4500, 2)

# %%
emb_df = pd.concat([pd.DataFrame(embedding) , pp_df.iloc[:, -2:]] , axis = 1 )
emb_df.columns = [ 'col_0', 'col_1', 'singer', 'song']

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
emb_df['singer_le'] = le.fit_transform(emb_df['singer']) ; emb_df
# Out:
#           col_0      col_1 singer                  song  singer_le
# 0      0.201286   1.309657     이정                   겨울봄        105
# 1      6.197201   7.758814     버즈                   거짓말         55
# 2      7.732862   6.599198    김광석           너무 깊이 생각하지마         13
# 3     12.716340   2.760269    소찬휘            크게 라디오를 켜고         64
# 4     11.671352  -0.787412     이적                당연한 것들        104
# ...         ...        ...    ...                   ...        ...
# 4495  10.151314  12.478089    장나라         I Love School        115
# 4496  -0.226143   4.375753    식케이  이해해줘 (Somebody Else)         73
# 4497   3.394830   7.753652     존박              내가 다 줄게요        130
# 4498  12.755475   3.512641    김창완                   동네길         26
# 4499   4.852580  11.455370    김완선             나홀로 뜰 앞에서         21
#
# [4500 rows x 5 columns]

# %%
emb_df['singer'].unique()
# Out:
# array(['이정', '버즈', '김광석', '소찬휘', '이적', '김연자', '김종국', '김예림', '박현빈', '거미',
#        '윤하', '백아연', '김건모', '나윤권', '전인권', '이효리', '이선희', '권진아', '카더가든',
#        '박진영', '양희은', '정동원', '바비 킴', '왁스', '더원', '잔나비', '임재범', '아이유',
#        '식케이', '넬', '이은미', '케이시', '오왠', '태진아', '김연지', '정승환', '휘성', '윤종신',
#        '김태우', '김창완', '정준일', '손승연', '하동균', '샘김', '서문탁', '박정현', '백지영',
#        '아이비', '소향', '이찬원', '조용필', '이승환', '폴킴', '임영웅', '로이킴', '황치열', '김정민',
#        '남진', 'XIA (준수)', '이수영', '헤이즈', '양파', '장재인', '에일리', '박완규', '김재환',
#        '김현식', '제시', '안예은', '박재정', '자우림', '김호중', '백예린', '알리', 'JUNIEL',
#        '보아', '송가인', '윤상', '임창정', '송하예', '윤미래', '이승철', '치즈', '제이', '송대관',
#        '수란', '양다일', '김연우', '영탁', '린', '에릭남', '나얼', '이문세', 'KCM', '홍대광',
#        '10CM', '박남정', '태연', '기리보이', '신해철', '엄정화', '이석훈', '김동률', '김범수',
#        '케이윌', '비', '장범준', '현숙', '정인', '인순이', '김현철', '김현성', '지아', '박상민',
#        '스텔라장', '루시드폴', '볼빨간사춘기', '윤도현', '별', '장나라', '박화요비', '장윤정', '한동근',
#        '유승우', '김완선', '적재', '선우정아', '김조한', '이진아', '규현', '나비', '싸이', '하현우',
#        '테이', '조성모', '박시환', '이승기', '스탠딩 에그', '검정치마', '존박', '김나영', '성시경',
#        '허각', '신승훈', '홍진영', '40', '정엽', '권인하', '박효신', '김경호'], dtype=object)

# %%
female = ['소찬휘', '김연자','김예림','거미',
       '윤하', '백아연',  '이효리', '이선희', '권진아', '양희은', '왁스',  '아이유',
       '이은미', '케이시',  '김연지',  '손승연',  '서문탁', '박정현', '백지영',
       '아이비', '소향', '이수영', '헤이즈', '양파', '장재인', '에일리', '제시', '안예은', '자우림', '백예린', '알리', 'JUNIEL',
       '보아', '송가인', '송하예', '윤미래', '치즈', '제이', '수란', '린', '태연', '엄정화', 
        '현숙', '정인', '인순이',  '지아', '스텔라장', '볼빨간사춘기',  '별', '장나라', '박화요비', '장윤정',
        '김완선', '선우정아', '이진아',  '나비',  '김나영', '홍진영']

emb_df['gender'] = emb_df['singer'].apply(lambda x : 'female' if x in female else 'male' ) ; emb_df
# Out:
#           col_0      col_1 singer                  song  singer_le  gender
# 0      0.201286   1.309657     이정                   겨울봄        105    male
# 1      6.197201   7.758814     버즈                   거짓말         55    male
# 2      7.732862   6.599198    김광석           너무 깊이 생각하지마         13    male
# 3     12.716340   2.760269    소찬휘            크게 라디오를 켜고         64  female
# 4     11.671352  -0.787412     이적                당연한 것들        104    male
# ...         ...        ...    ...                   ...        ...     ...
# 4495  10.151314  12.478089    장나라         I Love School        115  female
# 4496  -0.226143   4.375753    식케이  이해해줘 (Somebody Else)         73    male
# 4497   3.394830   7.753652     존박              내가 다 줄게요        130    male
# 4498  12.755475   3.512641    김창완                   동네길         26    male
# 4499   4.852580  11.455370    김완선             나홀로 뜰 앞에서         21  female
#
# [4500 rows x 6 columns]

# %%
sns.scatterplot( x = "col_0" , y = "col_1" , data = emb_df , hue = "gender")
plt.show()

# %%
sin = ['별',  '볼빨간사춘기' ,'백아연', '나비']
sample = emb_df.query(' singer in @sin')
sns.scatterplot( x = "col_0" , y = "col_1" , data = sample , hue = "singer")
plt.show()
# Out:
# /usr/local/lib/python3.8/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 48177 (\N{HANGUL SYLLABLE BAEG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.8/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 50500 (\N{HANGUL SYLLABLE A}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.8/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 50672 (\N{HANGUL SYLLABLE YEON}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.8/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 48380 (\N{HANGUL SYLLABLE BOL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.8/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 48744 (\N{HANGUL SYLLABLE BBAL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.8/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44036 (\N{HANGUL SYLLABLE GAN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.8/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49324 (\N{HANGUL SYLLABLE SA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.8/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 52632 (\N{HANGUL SYLLABLE CUN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.8/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44592 (\N{HANGUL SYLLABLE GI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.8/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 48324 (\N{HANGUL SYLLABLE BYEOL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.8/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 45208 (\N{HANGUL SYLLABLE NA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.8/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 48708 (\N{HANGUL SYLLABLE BI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
sin = ['스탠딩 에그','기리보이', '김호중', '이적']
sample = emb_df.query(' singer in @sin')
sns.scatterplot( x = "col_0" , y = "col_1" , data = sample , hue = "singer")
plt.show()
# Out:
# /usr/local/lib/python3.8/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51060 (\N{HANGUL SYLLABLE I}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.8/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51201 (\N{HANGUL SYLLABLE JEOG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.8/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44608 (\N{HANGUL SYLLABLE GIM}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.8/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 54840 (\N{HANGUL SYLLABLE HO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.8/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51473 (\N{HANGUL SYLLABLE JUNG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.8/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44592 (\N{HANGUL SYLLABLE GI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.8/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 47532 (\N{HANGUL SYLLABLE RI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.8/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 48372 (\N{HANGUL SYLLABLE BO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.8/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49828 (\N{HANGUL SYLLABLE SEU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.8/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 53472 (\N{HANGUL SYLLABLE TAEN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.8/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 46377 (\N{HANGUL SYLLABLE DING}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.8/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 50640 (\N{HANGUL SYLLABLE E}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.8/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44536 (\N{HANGUL SYLLABLE GEU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
sin = ['소향','기리보이',  '케이윌', 'JUNIEL']
sample = emb_df.query(' singer in @sin')
sns.scatterplot( x = "col_0" , y = "col_1" , data = sample , hue = "singer")
plt.show()
# Out:
# /usr/local/lib/python3.8/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49548 (\N{HANGUL SYLLABLE SO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.8/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 54693 (\N{HANGUL SYLLABLE HYANG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.8/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44592 (\N{HANGUL SYLLABLE GI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.8/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 47532 (\N{HANGUL SYLLABLE RI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.8/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 48372 (\N{HANGUL SYLLABLE BO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.8/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51060 (\N{HANGUL SYLLABLE I}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.8/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 52992 (\N{HANGUL SYLLABLE KE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.8/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 50956 (\N{HANGUL SYLLABLE WIL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
sin = ['루시드폴','박진영']
sample = emb_df.query(' singer in @sin')
sns.scatterplot( x = "col_0" , y = "col_1" , data = sample , hue = "singer")
plt.show()
# Out:
# /usr/local/lib/python3.8/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 48149 (\N{HANGUL SYLLABLE BAG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.8/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51652 (\N{HANGUL SYLLABLE JIN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.8/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 50689 (\N{HANGUL SYLLABLE YEONG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.8/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 47336 (\N{HANGUL SYLLABLE RU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.8/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49884 (\N{HANGUL SYLLABLE SI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.8/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 46300 (\N{HANGUL SYLLABLE DEU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.8/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 54260 (\N{HANGUL SYLLABLE POL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# 김광석 성시경 백아연 김예림 40 박화요비 서문탁 지아 치즈 양파 
# 스탠딩 에그 규현 나윤권

# %%
emb_df.groupby('singer').var()[['col_1', 'col_1']].mean(axis = 1) .sort_values( ascending = True )
# Out:
# singer
# 양파     0.824310
# 김건모    0.928339
# 박시환    0.956540
# 박재정    1.031059
# 윤하     1.045677
#          ...
# 백아연    2.278282
# 이진아    2.289755
# 헤이즈    2.355160
# 김동률    2.410748
# 테이     2.466798
# Length: 150, dtype: float32

# %%
sin = ['헤이즈']
sample = emb_df.query(' singer in @sin')
sns.scatterplot( x = "col_0" , y = "col_1" , data = sample , hue = "singer")
plt.show()
# Out:
# /usr/local/lib/python3.8/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 54756 (\N{HANGUL SYLLABLE HE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.8/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51060 (\N{HANGUL SYLLABLE I}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.8/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51592 (\N{HANGUL SYLLABLE JEU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# ## T-SNE

# %%
from sklearn.manifold import TSNE

tsne_np = TSNE(n_components = 2).fit_transform(pp_df.iloc[:, :-2])
tsne_df = pd.DataFrame(tsne_np, columns = ['component 0', 'component 1'])

# %%
tsne_df = pd.concat([ tsne_df , pp_df.iloc[:, -2:]] , axis = 1 )

# %%
tsne_df['gender'] = tsne_df['singer'].apply(lambda x : 'female' if x in female else 'male' ) ; tsne_df
# Out:
#       component 0  component 1 singer                  song  gender
# 0       14.990843     7.358544     이정                   겨울봄    male
# 1       -3.101455   -25.569595     버즈                   거짓말    male
# 2        6.302224    44.908798    김광석           너무 깊이 생각하지마    male
# 3        6.362890    22.548239    소찬휘            크게 라디오를 켜고  female
# 4       27.759314     5.249477     이적                당연한 것들    male
# ...           ...          ...    ...                   ...     ...
# 4495   -40.570969    10.537805    장나라         I Love School  female
# 4496    21.540390   -33.838291    식케이  이해해줘 (Somebody Else)    male
# 4497   -12.277713   -45.777313     존박              내가 다 줄게요    male
# 4498    10.420829   -29.062904    김창완                   동네길    male
# 4499   -62.613949   -17.710184    김완선             나홀로 뜰 앞에서  female
#
# [4500 rows x 5 columns]

# %%
sns.scatterplot( x = "component 0" , y = "component 1" , data = tsne_df , hue = "gender")
plt.show()

# %%
sin = ['성시경',  '치즈']
sample = tsne_df.query(' singer in @sin')
sns.scatterplot( x = "component 0" , y = "component 1" , data = sample , hue = "singer")
plt.show()
# Out:
# /usr/local/lib/python3.8/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 52824 (\N{HANGUL SYLLABLE CI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.8/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51592 (\N{HANGUL SYLLABLE JEU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.8/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49457 (\N{HANGUL SYLLABLE SEONG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.8/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49884 (\N{HANGUL SYLLABLE SI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.8/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44221 (\N{HANGUL SYLLABLE GYEONG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# ## Factor Analyzer

# %%
from factor_analyzer import FactorAnalyzer
from factor_analyzer.factor_analyzer import calculate_kmo

kmo_all,kmo_model=calculate_kmo(pp_df.iloc[:, :-2])

kmo_model # FA 의미 있음
# Out:
# 0.7923604421324952

# %%
pp_df['col'] = pp_df['singer'] + '_'+ pp_df['song'] 
df_fa = pd.concat([pp_df.iloc[:, :-3] , pp_df.iloc[:, -1]] , axis = 1 )
df_fa = df_fa.T
df_fa.columns = list(df_fa.iloc[-1, :])
df_fa = df_fa.iloc[:-1, :]

# %%
# fa = FactorAnalyzer()

# fa.fit( df_fa )
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [220], in <cell line: 3>()
#       1 fa = FactorAnalyzer()
# ----> 3 fa.fit( df_fa )
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/factor_analyzer/factor_analyzer.py:651, in FactorAnalyzer.fit(self, X, y)
#     649     loadings = self._fit_principal(X)
#     650 else:
# --> 651     loadings = self._fit_factor_analysis(corr_mtx)
#     653 # only used if we do an oblique rotations;
#     654 # default rotation matrix to None
#     655 phi = None
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/factor_analyzer/factor_analyzer.py:563, in FactorAnalyzer._fit_factor_analysis(self, corr_mtx)
#     560     objective = self._fit_uls_objective
#     562 # use scipy to perform the actual minimization
# --> 563 res = minimize(
#     564     objective,
#     565     start,
#     566     method="L-BFGS-B",
#     567     bounds=bounds,
#     568     options={"maxiter": 1000},
#     569     args=(corr_mtx, self.n_factors),
#     570 )
#     572 if not res.success:
#     573     warnings.warn(f"Failed to converge: {res.message}")
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/scipy/optimize/_minimize.py:623, in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     620     return _minimize_newtoncg(fun, x0, args, jac, hess, hessp, callback,
#     621                               **options)
#     622 elif meth == 'l-bfgs-b':
# --> 623     return _minimize_lbfgsb(fun, x0, args, jac, bounds,
#     624                             callback=callback, **options)
#     625 elif meth == 'tnc':
#     626     return _minimize_tnc(fun, x0, args, jac, bounds, callback=callback,
#     627                          **options)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/scipy/optimize/lbfgsb.py:306, in _minimize_lbfgsb(fun, x0, args, jac, bounds, disp, maxcor, ftol, gtol, eps, maxfun, maxiter, iprint, callback, maxls, finite_diff_rel_step, **unknown_options)
#     303     else:
#     304         iprint = disp
# --> 306 sf = _prepare_scalar_function(fun, x0, jac=jac, args=args, epsilon=eps,
#     307                               bounds=new_bounds,
#     308                               finite_diff_rel_step=finite_diff_rel_step)
#     310 func_and_grad = sf.fun_and_grad
#     312 fortran_int = _lbfgsb.types.intvar.dtype
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/scipy/optimize/optimize.py:261, in _prepare_scalar_function(fun, x0, jac, args, bounds, epsilon, finite_diff_rel_step, hess)
#     257     bounds = (-np.inf, np.inf)
#     259 # ScalarFunction caches. Reuse of fun(x) during grad
#     260 # calculation reduces overall function evaluations.
# --> 261 sf = ScalarFunction(fun, x0, args, grad, hess,
#     262                     finite_diff_rel_step, bounds, epsilon=epsilon)
#     264 return sf
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/scipy/optimize/_differentiable_functions.py:159, in ScalarFunction.__init__(self, fun, x0, args, grad, hess, finite_diff_rel_step, finite_diff_bounds, epsilon)
#     155         self.g = approx_derivative(fun_wrapped, self.x, f0=self.f,
#     156                                    **finite_diff_options)
#     158 self._update_grad_impl = update_grad
# --> 159 self._update_grad()
#     161 # Hessian Evaluation
#     162 if callable(hess):
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/scipy/optimize/_differentiable_functions.py:238, in ScalarFunction._update_grad(self)
#     236 def _update_grad(self):
#     237     if not self.g_updated:
# --> 238         self._update_grad_impl()
#     239         self.g_updated = True
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/scipy/optimize/_differentiable_functions.py:155, in ScalarFunction.__init__.<locals>.update_grad()
#     153 self._update_fun()
#     154 self.ngev += 1
# --> 155 self.g = approx_derivative(fun_wrapped, self.x, f0=self.f,
#     156                            **finite_diff_options)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/scipy/optimize/_numdiff.py:486, in approx_derivative(fun, x0, method, rel_step, abs_step, f0, bounds, sparsity, as_linear_operator, args, kwargs)
#     483     use_one_sided = False
#     485 if sparsity is None:
# --> 486     return _dense_difference(fun_wrapped, x0, f0, h,
#     487                              use_one_sided, method)
#     488 else:
#     489     if not issparse(sparsity) and len(sparsity) == 2:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/scipy/optimize/_numdiff.py:557, in _dense_difference(fun, x0, f0, h, use_one_sided, method)
#     555     x = x0 + h_vecs[i]
#     556     dx = x[i] - x0[i]  # Recompute dx as exactly representable number.
# --> 557     df = fun(x) - f0
#     558 elif method == '3-point' and use_one_sided[i]:
#     559     x1 = x0 + h_vecs[i]
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/scipy/optimize/_numdiff.py:437, in approx_derivative.<locals>.fun_wrapped(x)
#     436 def fun_wrapped(x):
# --> 437     f = np.atleast_1d(fun(x, *args, **kwargs))
#     438     if f.ndim > 1:
#     439         raise RuntimeError("`fun` return value has "
#     440                            "more than 1 dimension.")
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/scipy/optimize/_differentiable_functions.py:134, in ScalarFunction.__init__.<locals>.fun_wrapped(x)
#     130 self.nfev += 1
#     131 # Send a copy because the user may overwrite it.
#     132 # Overwriting results in undefined behaviour because
#     133 # fun(self.x) will change self.x, with the two no longer linked.
# --> 134 return fun(np.copy(x), *args)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/factor_analyzer/factor_analyzer.py:341, in FactorAnalyzer._fit_uls_objective(psi, corr_mtx, n_factors)
#     338 np.fill_diagonal(corr_mtx, 1 - psi)
#     340 # get the eigen values and vectors for n_factors
# --> 341 values, vectors = sp.linalg.eigh(corr_mtx)
#     342 values = values[::-1]
#     344 # this is a bit of a hack, borrowed from R's `fac()` function;
#     345 # if values are smaller than the smallest representable positive
#     346 # number * 100, set them to that number instead.
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/scipy/linalg/decomp.py:545, in eigh(a, b, lower, eigvals_only, overwrite_a, overwrite_b, turbo, eigvals, type, check_finite, subset_by_index, subset_by_value, driver)
#     542         lwork_args = {'lwork': lw}
#     544     drv_args.update({'lower': lower, 'compute_v': 0 if _job == "N" else 1})
# --> 545     w, v, *other_args, info = drv(a=a1, **drv_args, **lwork_args)
#     547 else:  # Generalized problem
#     548     # 'gvd' doesn't have lwork query
#     549     if driver == "gvd":
#
# KeyboardInterrupt:

# %%
# fa.loadings_.shape

# %%
# gender classification 후 note 조정 어떻게 할건지 알아보기
